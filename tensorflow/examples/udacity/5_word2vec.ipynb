# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'anarchism', 'a', 'term', 'of', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.044914
# Nearest to no: pendants, anthology, jail, piso, telegraphy, frowned, razor, goaltender,
# Nearest to such: bsi, nevsky, wf, rabba, backstreet, betraying, nadezhda, tlatelolco,
# Nearest to system: chaco, removable, pepper, leander, aquitaine, guido, plummeted, inhabited,
# Nearest to are: perils, basayev, vests, conurbation, mousse, iommi, parked, cart,
# Nearest to on: gomez, speller, idempotent, cults, bretons, tattooed, carry, reside,
# Nearest to while: pernambuco, alcohols, juries, fpga, hayes, dwarves, emoticon, abbasid,
# Nearest to its: novi, vet, jolly, gormenghast, kgb, interrupt, samos, composite,
# Nearest to new: watt, aspectual, snowmobiles, brenda, aerial, menthol, ally, sickly,
# Nearest to people: uris, ponds, colombo, considering, environs, prev, heuristic, spp,
# Nearest to during: bonnet, intellectual, cmd, asser, tamburlaine, ruler, lenses, reunion,
# Nearest to about: diomedea, gala, hopelessly, magellanic, katharina, lookup, ctus, explainable,
# Nearest to american: permitting, tabasco, celebratory, cocalus, halfback, cisc, wooded, ayer,
# Nearest to may: larp, chatham, restless, maritimes, embarking, antagonistic, alkalis, sai,
# Nearest to many: palmyra, montfort, suborders, disconnect, rigorously, inline, liu, cole,
# Nearest to one: aggressor, sprinkling, striping, familia, cannes, anthologies, cosets, filthy,
# Nearest to s: bounding, haganah, yamaha, titicaca, cucumbers, gazette, issuance, enacting,
# Average loss at step 2000: 4.356720
# Average loss at step 4000: 3.862377
# Average loss at step 6000: 3.783327
# Average loss at step 8000: 3.689207
# Average loss at step 10000: 3.618103
# Nearest to no: jail, been, anthology, pendants, it, inaccuracy, fudge, popularised,
# Nearest to such: well, bsi, rosenbaum, rabba, thwarted, backstreet, resign, classified,
# Nearest to system: student, pepper, removable, leander, aquitaine, methyl, plummeted, guido,
# Nearest to are: were, is, have, quarrying, was, include, migs, nippon,
# Nearest to on: in, at, qin, deviation, speller, cultural, sibm, by,
# Nearest to while: protector, bodhidharma, sims, mumia, pedophilia, gellius, alcohols, fpga,
# Nearest to its: the, their, his, echoed, her, emphatically, nanotubes, photos,
# Nearest to new: aspectual, ally, menthol, city, hakim, knowing, connacht, dicrostonyx,
# Nearest to people: colombo, xserve, environs, rhea, ontogeny, silk, isaacs, add,
# Nearest to during: bonnet, stellated, ruler, border, intellectual, after, broadway, asser,
# Nearest to about: gala, magellanic, axels, shaffer, kutch, alcs, journalists, diomedea,
# Nearest to american: newest, resonate, tabasco, pyrotechnics, helier, neoliberalism, respected, helios,
# Nearest to may: can, would, chatham, lasting, beds, marburg, prices, asymptotically,
# Nearest to many: some, these, sibilants, montfort, activity, wittelsbach, tired, cell,
# Nearest to one: three, two, four, seven, six, five, sancta, eight,
# Nearest to s: his, and, bounding, trafalgar, nanotubes, scorpio, retail, spins,
# Average loss at step 12000: 3.602336
# Average loss at step 14000: 3.567316
# Average loss at step 16000: 3.406654
# Average loss at step 18000: 3.460092
# Average loss at step 20000: 3.539364
# Nearest to no: jail, conceptualization, spalding, stable, hco, popularised, junit, tiled,
# Nearest to such: well, rosenbaum, bsi, classified, thwarted, known, holistic, claudius,
# Nearest to system: student, transposed, methyl, removable, plummeted, leander, pepper, meo,
# Nearest to are: were, is, have, migs, was, flirting, nippon, perimeter,
# Nearest to on: at, in, upon, congregation, oliva, palme, correct, under,
# Nearest to while: but, where, when, protector, and, upbeat, placidia, tallinn,
# Nearest to its: their, his, the, echoed, her, gear, remedies, coffin,
# Nearest to new: aspectual, city, knowing, hakim, institute, connacht, ally, cheer,
# Nearest to people: colombo, ontogeny, xserve, argue, silk, americans, add, rhea,
# Nearest to during: after, in, bonnet, at, entire, intellectual, broadway, pathophysiology,
# Nearest to about: gala, alcs, magellanic, jadwiga, kutch, willard, hopelessly, agis,
# Nearest to american: australian, british, german, helier, canadian, english, newest, sasl,
# Nearest to may: can, would, will, must, lasting, should, to, chatham,
# Nearest to many: some, these, other, several, all, sibilants, exposure, ignoring,
# Nearest to one: two, three, four, six, seven, eight, five, nine,
# Nearest to s: trafalgar, ragged, heater, spins, fearless, magi, hitchhiker, skating,
# Average loss at step 22000: 3.501486
# Average loss at step 24000: 3.490189
# Average loss at step 26000: 3.482771
# Average loss at step 28000: 3.477492
# Average loss at step 30000: 3.498859
# Nearest to no: jail, conceptualization, spalding, a, idiosyncratic, tiled, there, stable,
# Nearest to such: well, known, these, classified, crumbs, rosenbaum, claudius, bsi,
# Nearest to system: systems, credence, student, confluence, transposed, sound, arduous, removable,
# Nearest to are: were, is, have, be, migs, those, carolyn, include,
# Nearest to on: in, upon, channel, at, during, around, from, through,
# Nearest to while: but, when, although, where, however, were, ghq, louvre,
# Nearest to its: their, the, his, gear, echoed, youngsters, her, remedies,
# Nearest to new: city, whole, aspectual, knowing, hakim, great, ally, dicrostonyx,
# Nearest to people: americans, colombo, countries, ontogeny, men, xserve, argue, provinces,
# Nearest to during: after, in, before, entire, when, stellated, on, since,
# Nearest to about: gala, enjoyment, hopelessly, willard, kutch, brushing, launchers, jadwiga,
# Nearest to american: british, english, australian, canadian, helier, newest, italian, dutch,
# Nearest to may: can, would, will, must, could, should, might, chatham,
# Nearest to many: some, several, these, all, other, most, ignoring, their,
# Nearest to one: two, seven, three, four, five, six, eight, speeding,
# Nearest to s: his, skating, claymore, fearless, engelbart, tomography, havens, riff,
# Average loss at step 32000: 3.505107
# Average loss at step 34000: 3.497164
# Average loss at step 36000: 3.455013
# Average loss at step 38000: 3.304320
# Average loss at step 40000: 3.429539
# Nearest to no: spalding, conceptualization, jail, stable, filial, rectangle, twitching, demoted,
# Nearest to such: well, these, known, classified, claudius, regarded, using, bsi,
# Nearest to system: systems, plummeted, methyl, sound, credence, removable, transposed, student,
# Nearest to are: were, have, is, include, be, nippon, can, but,
# Nearest to on: upon, at, palme, congregation, abroad, fountains, gathers, sibm,
# Nearest to while: although, when, where, but, were, however, including, plausible,
# Nearest to its: their, his, her, the, diplomatic, youngsters, gear, stabilizer,
# Nearest to new: city, whole, aspectual, ally, hakim, uefa, bard, offical,
# Nearest to people: americans, countries, languages, men, children, those, argue, mushrooms,
# Nearest to during: after, before, at, in, since, stellated, entire, until,
# Nearest to about: gala, enjoyment, over, mdi, rebuilt, willard, brushing, hellish,
# Nearest to american: australian, british, helier, english, italian, russian, newest, canadian,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to many: some, several, these, most, various, keepers, both, all,
# Nearest to one: seven, four, two, six, eight, five, three, nine,
# Nearest to s: dimer, his, skating, petn, mexican, backwardness, and, spreads,
# Average loss at step 42000: 3.436945
# Average loss at step 44000: 3.453787
# Average loss at step 46000: 3.450072
# Average loss at step 48000: 3.355822
# Average loss at step 50000: 3.380172
# Nearest to no: any, spalding, a, conceptualization, americanized, rainfall, tuva, fascism,
# Nearest to such: well, these, known, many, classified, dyeing, regarded, holistic,
# Nearest to system: systems, plummeted, methyl, sound, marat, hetzel, allotment, melt,
# Nearest to are: were, have, is, these, those, include, nippon, was,
# Nearest to on: upon, in, harvest, from, congregation, oliva, within, through,
# Nearest to while: when, although, however, where, but, though, before, including,
# Nearest to its: their, his, her, the, diplomatic, stabilizer, our, youngsters,
# Nearest to new: great, whole, pda, cheer, dalek, city, ally, institute,
# Nearest to people: children, men, americans, serapeum, kaczynski, homes, countries, nep,
# Nearest to during: after, before, in, since, at, until, when, entire,
# Nearest to about: gala, rebuilt, supernaturally, katharina, bfi, over, abramovich, launchers,
# Nearest to american: australian, british, italian, english, helier, russian, newest, mtsho,
# Nearest to may: can, would, will, must, should, could, might, cannot,
# Nearest to many: some, several, these, various, both, such, most, other,
# Nearest to one: two, six, seven, four, eight, three, five, nine,
# Nearest to s: fearless, dimer, innocuous, petn, his, whose, tyrol, bourgeois,
# Average loss at step 52000: 3.432736
# Average loss at step 54000: 3.426460
# Average loss at step 56000: 3.437994
# Average loss at step 58000: 3.395851
# Average loss at step 60000: 3.394964
# Nearest to no: any, tuva, rainfall, conceptualization, spalding, americanized, msx, little,
# Nearest to such: well, these, known, many, regarded, dyeing, classified, thwarted,
# Nearest to system: systems, allotment, methyl, plummeted, howlin, jeter, model, guide,
# Nearest to are: were, is, have, be, include, nippon, those, was,
# Nearest to on: upon, in, channel, through, under, within, oliva, fountains,
# Nearest to while: although, when, including, before, however, where, though, but,
# Nearest to its: their, his, the, her, stabilizer, dependency, leyden, echoed,
# Nearest to new: ally, whole, pda, cheer, great, city, offical, aspectual,
# Nearest to people: men, americans, children, countries, groups, those, serapeum, homes,
# Nearest to during: after, before, although, until, since, when, entire, in,
# Nearest to about: gala, supernaturally, over, katharina, rebuilt, aragonese, bfi, diomedea,
# Nearest to american: australian, british, italian, english, irish, helier, canadian, african,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to many: some, several, these, various, most, both, such, all,
# Nearest to one: two, four, seven, six, eight, three, five, nine,
# Nearest to s: gonzalo, nicolson, bazille, husserl, campo, backwardness, marathas, cyborg,
# Average loss at step 62000: 3.238784
# Average loss at step 64000: 3.254314
# Average loss at step 66000: 3.400224
# Average loss at step 68000: 3.396367
# Average loss at step 70000: 3.358973
# Nearest to no: little, tuva, fascism, rainfall, any, countenance, conceptualization, humphreys,
# Nearest to such: these, well, known, many, regarded, classified, dyeing, claudius,
# Nearest to system: systems, allotment, methyl, jeter, plummeted, dll, thesis, sound,
# Nearest to are: were, have, include, is, these, be, those, acrobatics,
# Nearest to on: upon, through, in, within, at, under, deviation, accidentals,
# Nearest to while: although, when, however, though, where, before, including, and,
# Nearest to its: their, his, the, her, brazzaville, stabilizer, diplomatic, our,
# Nearest to new: whole, cheer, fundamental, aspectual, pda, connacht, deforest, great,
# Nearest to people: men, americans, children, homes, persons, countries, women, authorities,
# Nearest to during: after, before, in, since, until, when, although, across,
# Nearest to about: gala, over, aragonese, rebuilt, katharina, launchers, detailed, bfi,
# Nearest to american: british, italian, australian, english, canadian, irish, newest, scottish,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to many: some, several, various, these, all, most, numerous, evolved,
# Nearest to one: two, six, seven, eight, four, three, five, nine,
# Nearest to s: whose, skating, petn, athenaeum, metropolises, fearless, the, camille,
# Average loss at step 72000: 3.374098
# Average loss at step 74000: 3.344800
# Average loss at step 76000: 3.320368
# Average loss at step 78000: 3.349316
# Average loss at step 80000: 3.383818
# Nearest to no: little, fascism, americanized, any, rainfall, hco, meteor, folktales,
# Nearest to such: well, these, known, follows, regarded, dyeing, classified, holistic,
# Nearest to system: systems, jeter, allotment, methyl, melt, plummeted, model, hermas,
# Nearest to are: were, include, is, have, these, including, those, while,
# Nearest to on: upon, in, through, under, within, during, at, sibm,
# Nearest to while: although, when, though, before, including, and, but, however,
# Nearest to its: their, his, her, the, your, stabilizer, brazzaville, echoed,
# Nearest to new: pda, ally, aspectual, modern, cheer, great, connacht, submarine,
# Nearest to people: men, children, persons, americans, homes, countries, god, philosophers,
# Nearest to during: after, before, in, when, until, since, despite, although,
# Nearest to about: gala, over, rebuilt, launchers, aragonese, bfi, barter, katharina,
# Nearest to american: british, english, australian, international, irish, italian, canadian, wargame,
# Nearest to may: can, could, will, would, must, should, might, cannot,
# Nearest to many: some, several, these, various, most, few, numerous, all,
# Nearest to one: seven, six, two, four, eight, three, five, nine,
# Nearest to s: splendor, hawai, alarm, hydrochloride, executors, erythrocytes, metropolises, bourgeois,
# Average loss at step 82000: 3.405630
# Average loss at step 84000: 3.407924
# Average loss at step 86000: 3.388404
# Average loss at step 88000: 3.348810
# Average loss at step 90000: 3.367166
# Nearest to no: any, little, americanized, valid, conceptualization, fascism, spared, rainfall,
# Nearest to such: well, these, known, regarded, follows, certain, classified, many,
# Nearest to system: systems, allotment, jeter, dll, hermas, thr, removable, sound,
# Nearest to are: were, is, include, have, these, mein, nippon, migs,
# Nearest to on: upon, under, at, in, against, hovered, through, tattooed,
# Nearest to while: although, when, before, though, after, during, were, including,
# Nearest to its: their, his, her, the, your, stabilizer, brazzaville, diplomatic,
# Nearest to new: great, ally, modern, fundamental, submarine, surrogate, pda, uefa,
# Nearest to people: children, men, god, homes, persons, americans, women, philosophers,
# Nearest to during: after, before, in, until, while, at, under, when,
# Nearest to about: gala, launchers, over, rebuilt, barter, aragonese, katharina, bfi,
# Nearest to american: british, australian, italian, english, irish, wargame, french, russian,
# Nearest to may: can, could, would, will, must, should, might, cannot,
# Nearest to many: some, several, these, various, most, numerous, few, all,
# Nearest to one: seven, two, four, six, eight, three, five, zero,
# Nearest to s: whose, his, tomography, virtualization, her, hawai, skating, splendor,
# Average loss at step 92000: 3.402030
# Average loss at step 94000: 3.246252
# Average loss at step 96000: 3.360222
# Average loss at step 98000: 3.244121
# Average loss at step 100000: 3.356694
# Nearest to no: any, little, spared, sparking, americanized, planckian, rainfall, tara,
# Nearest to such: well, known, these, many, regarded, follows, classified, certain,
# Nearest to system: systems, allotment, dll, model, process, jeter, plummeted, hermas,
# Nearest to are: were, have, although, including, is, those, be, these,
# Nearest to on: upon, under, in, through, within, at, against, fountains,
# Nearest to while: although, when, before, though, after, but, however, during,
# Nearest to its: their, his, her, the, your, diplomatic, stabilizer, leyden,
# Nearest to new: pda, different, uefa, modern, maastricht, surreal, ally, great,
# Nearest to people: children, men, americans, persons, god, fans, women, jews,
# Nearest to during: after, before, in, until, when, since, although, despite,
# Nearest to about: gala, launchers, over, katharina, aragonese, rebuilt, barter, jurassic,
# Nearest to american: british, canadian, australian, italian, scottish, english, wargame, indian,
# Nearest to may: can, could, would, should, must, might, will, cannot,
# Nearest to many: some, several, these, various, few, all, numerous, those,
# Nearest to one: two, seven, six, four, five, three, eight, nine,
# Nearest to s: whose, his, the, splendor, bounding, bury, petn, camille,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/extmath.py:360: UserWarning: The number of power iterations is increased to 7 to achieve higher precision.
#   warnings.warn("The number of power iterations is increased to 7 to "

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
